# %% [markdown]
# <a href="https://colab.research.google.com/github/MovieHub21/BUG-BOT/blob/master/RVC_For_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title 克隆仓库
# %rm -rf /content/RVC-Retrieval-based-Voice-Conversion-Colab
# %cd /content
# !git clone --depth=1 https://github.com/yushentang/RVC-Retrieval-based-Voice-Conversion-Colab.git
# %cd /content/RVC-Retrieval-based-Voice-Conversion-Colab
# !mkdir -p pretrained uvr5_weights

# %%
# @title 配置运行环境
# !pip install -r requirements.txt
# Out:
# Collecting fairseq@ git+https://github.com/One-sixth/fairseq.git (from -r requirements.txt (line 7))
#   Cloning https://github.com/One-sixth/fairseq.git to /tmp/pip-install-1txwqq9s/fairseq_ce647a384d0248f6a23f35f8c2056fdc
#   Running command git clone --filter=blob:none --quiet https://github.com/One-sixth/fairseq.git /tmp/pip-install-1txwqq9s/fairseq_ce647a384d0248f6a23f35f8c2056fdc
#   Resolved https://github.com/One-sixth/fairseq.git to commit 44800430a728c2216fd1cf1e8daa672f50dfacba
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Ignoring onnxruntime: markers 'sys_platform == "darwin"' don't match your environment
# Requirement already satisfied: joblib>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (1.5.3)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (0.60.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (1.16.3)
# Collecting librosa==0.10.2 (from -r requirements.txt (line 5))
#   Downloading librosa-0.10.2-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: llvmlite in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (0.43.0)
# Collecting faiss-cpu (from -r requirements.txt (line 8))
#   Downloading faiss_cpu-1.13.2-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (7.6 kB)
# Collecting gradio==3.48.0 (from -r requirements.txt (line 9))
#   Downloading gradio-3.48.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: Cython in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (3.0.12)
# Requirement already satisfied: pydub>=0.25.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (0.25.1)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (0.13.1)
# Collecting ffmpeg-python>=0.2.0 (from -r requirements.txt (line 13))
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorboardX (from -r requirements.txt (line 14))
#   Downloading tensorboardx-2.6.5-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 15)) (3.1.6)
# Collecting json5 (from -r requirements.txt (line 16))
#   Downloading json5-0.14.0-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: Markdown in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 17)) (3.10.2)
# Collecting matplotlib<3.10 (from -r requirements.txt (line 18))
#   Downloading matplotlib-3.9.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: matplotlib-inline>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 19)) (0.2.1)
# Collecting praat-parselmouth>=0.4.2 (from -r requirements.txt (line 20))
#   Downloading praat_parselmouth-0.4.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.9 kB)
# Requirement already satisfied: Pillow>=9.1.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 21)) (11.3.0)
# Collecting resampy>=0.4.2 (from -r requirements.txt (line 22))
#   Downloading resampy-0.4.3-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 23)) (1.6.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 24)) (2.20.0)
# Requirement already satisfied: tqdm>=4.63.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 25)) (4.67.3)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 26)) (6.5.1)
# Requirement already satisfied: Werkzeug>=2.2.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 27)) (3.1.8)
# Requirement already satisfied: uc-micro-py>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 28)) (2.0.0)
# Requirement already satisfied: sympy>=1.11.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 29)) (1.14.0)
# Requirement already satisfied: tabulate>=0.8.10 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 30)) (0.9.0)
# Requirement already satisfied: PyYAML>=6.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 31)) (6.0.3)
# Requirement already satisfied: pyasn1>=0.4.8 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 32)) (0.6.3)
# Requirement already satisfied: pyasn1-modules>=0.2.8 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 33)) (0.4.2)
# Requirement already satisfied: fsspec>=2022.11.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 34)) (2025.3.0)
# Requirement already satisfied: absl-py>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 35)) (1.4.0)
# Requirement already satisfied: audioread in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 36)) (3.1.0)
# Requirement already satisfied: uvicorn>=0.21.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 37)) (0.46.0)
# Collecting colorama>=0.4.5 (from -r requirements.txt (line 38))
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting pyworld==0.3.2 (from -r requirements.txt (line 39))
#   Downloading pyworld-0.3.2.tar.gz (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.4/214.4 kB 11.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: httpx in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 40)) (0.28.1)
# Collecting onnxruntime-gpu (from -r requirements.txt (line 42))
#   Downloading onnxruntime_gpu-1.26.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.6 kB)
# Collecting torchcrepe==0.0.23 (from -r requirements.txt (line 43))
#   Downloading torchcrepe-0.0.23-py3-none-any.whl.metadata (7.8 kB)
# Collecting fastapi==0.88 (from -r requirements.txt (line 44))
#   Downloading fastapi-0.88.0-py3-none-any.whl.metadata (24 kB)
# Collecting torchfcpe (from -r requirements.txt (line 45))
#   Downloading torchfcpe-0.0.4-py3-none-any.whl.metadata (2.0 kB)
# Collecting ffmpy==0.3.1 (from -r requirements.txt (line 46))
#   Downloading ffmpy-0.3.1.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dotenv>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 47)) (1.2.2)
# Collecting av (from -r requirements.txt (line 48))
#   Downloading av-17.0.1-cp311-abi3-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa==0.10.2->-r requirements.txt (line 5)) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa==0.10.2->-r requirements.txt (line 5)) (1.9.0)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa==0.10.2->-r requirements.txt (line 5)) (1.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.12/dist-packages (from librosa==0.10.2->-r requirements.txt (line 5)) (4.15.0)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa==0.10.2->-r requirements.txt (line 5)) (0.5)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa==0.10.2->-r requirements.txt (line 5)) (1.1.2)
# Collecting aiofiles<24.0,>=22.0 (from gradio==3.48.0->-r requirements.txt (line 9))
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.48.0->-r requirements.txt (line 9)) (5.5.0)
# Collecting gradio-client==0.6.1 (from gradio==3.48.0->-r requirements.txt (line 9))
#   Downloading gradio_client-0.6.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: huggingface-hub>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.48.0->-r requirements.txt (line 9)) (1.11.0)
# Collecting importlib-resources<7.0,>=1.3 (from gradio==3.48.0->-r requirements.txt (line 9))
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting markupsafe~=2.0 (from gradio==3.48.0->-r requirements.txt (line 9))
#   Downloading MarkupSafe-2.1.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting numpy (from -r requirements.txt (line 3))
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.48.0->-r requirements.txt (line 9)) (3.11.8)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from gradio==3.48.0->-r requirements.txt (line 9)) (26.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.48.0->-r requirements.txt (line 9)) (2.2.2)
# Collecting Pillow>=9.1.1 (from -r requirements.txt (line 21))
#   Downloading pillow-10.4.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from gradio==3.48.0->-r requirements.txt (line 9)) (2.12.3)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.12/dist-packages (from gradio==3.48.0->-r requirements.txt (line 9)) (0.0.26)
# Requirement already satisfied: requests~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.48.0->-r requirements.txt (line 9)) (2.32.4)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.48.0->-r requirements.txt (line 9)) (2.10.0)
# Collecting websockets<12.0,>=10.0 (from gradio==3.48.0->-r requirements.txt (line 9))
#   Downloading websockets-11.0.3-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from torchcrepe==0.0.23->-r requirements.txt (line 43)) (2.10.0+cu128)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (from torchcrepe==0.0.23->-r requirements.txt (line 43)) (2.10.0+cu128)
# Collecting pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4 (from gradio==3.48.0->-r requirements.txt (line 9))
#   Downloading pydantic-1.10.26-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.1/155.1 kB 15.6 MB/s eta 0:00:00
# Collecting starlette==0.22.0 (from fastapi==0.88->-r requirements.txt (line 44))
#   Downloading starlette-0.22.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.12/dist-packages (from starlette==0.22.0->fastapi==0.88->-r requirements.txt (line 44)) (4.13.0)
# Requirement already satisfied: cffi in /usr/local/lib/python3.12/dist-packages (from fairseq@ git+https://github.com/One-sixth/fairseq.git->-r requirements.txt (line 7)) (2.0.0)
# Collecting hydra-core>=1.3.2 (from fairseq@ git+https://github.com/One-sixth/fairseq.git->-r requirements.txt (line 7))
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.12/dist-packages (from fairseq@ git+https://github.com/One-sixth/fairseq.git->-r requirements.txt (line 7)) (2.3.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from fairseq@ git+https://github.com/One-sixth/fairseq.git->-r requirements.txt (line 7)) (2025.11.3)
# Collecting sacrebleu>=1.4.12 (from fairseq@ git+https://github.com/One-sixth/fairseq.git->-r requirements.txt (line 7))
#   Downloading sacrebleu-2.6.0-py3-none-any.whl.metadata (39 kB)
# Collecting bitarray (from fairseq@ git+https://github.com/One-sixth/fairseq.git->-r requirements.txt (line 7))
#   Downloading bitarray-3.8.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (34 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from ffmpeg-python>=0.2.0->-r requirements.txt (line 13)) (1.0.0)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.12/dist-packages (from tensorboardX->-r requirements.txt (line 14)) (5.29.6)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.10->-r requirements.txt (line 18)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.10->-r requirements.txt (line 18)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.10->-r requirements.txt (line 18)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.10->-r requirements.txt (line 18)) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.10->-r requirements.txt (line 18)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.10->-r requirements.txt (line 18)) (2.9.0.post0)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.12/dist-packages (from matplotlib-inline>=0.1.3->-r requirements.txt (line 19)) (5.7.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 23)) (3.6.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard->-r requirements.txt (line 24)) (1.80.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard->-r requirements.txt (line 24)) (75.2.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard->-r requirements.txt (line 24)) (0.7.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.11.1->-r requirements.txt (line 29)) (1.3.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn>=0.21.1->-r requirements.txt (line 37)) (8.3.3)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn>=0.21.1->-r requirements.txt (line 37)) (0.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx->-r requirements.txt (line 40)) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx->-r requirements.txt (line 40)) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx->-r requirements.txt (line 40)) (3.13)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu->-r requirements.txt (line 42)) (25.12.19)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from torchfcpe->-r requirements.txt (line 45)) (0.8.2)
# Collecting local-attention (from torchfcpe->-r requirements.txt (line 45))
#   Downloading local_attention-1.11.2-py3-none-any.whl.metadata (929 bytes)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair<6.0,>=4.2.0->gradio==3.48.0->-r requirements.txt (line 9)) (4.26.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair<6.0,>=4.2.0->gradio==3.48.0->-r requirements.txt (line 9)) (2.20.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi->fairseq@ git+https://github.com/One-sixth/fairseq.git->-r requirements.txt (line 7)) (3.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.14.0->gradio==3.48.0->-r requirements.txt (line 9)) (3.29.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.14.0->gradio==3.48.0->-r requirements.txt (line 9)) (1.4.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.14.0->gradio==3.48.0->-r requirements.txt (line 9)) (0.24.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from hydra-core>=1.3.2->fairseq@ git+https://github.com/One-sixth/fairseq.git->-r requirements.txt (line 7)) (4.9.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio==3.48.0->-r requirements.txt (line 9)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio==3.48.0->-r requirements.txt (line 9)) (2026.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa==0.10.2->-r requirements.txt (line 5)) (4.9.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib<3.10->-r requirements.txt (line 18)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests~=2.0->gradio==3.48.0->-r requirements.txt (line 9)) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests~=2.0->gradio==3.48.0->-r requirements.txt (line 9)) (2.5.0)
# Collecting portalocker (from sacrebleu>=1.4.12->fairseq@ git+https://github.com/One-sixth/fairseq.git->-r requirements.txt (line 7))
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from sacrebleu>=1.4.12->fairseq@ git+https://github.com/One-sixth/fairseq.git->-r requirements.txt (line 7)) (6.1.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe==0.0.23->-r requirements.txt (line 43)) (3.6.1)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe==0.0.23->-r requirements.txt (line 43)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe==0.0.23->-r requirements.txt (line 43)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe==0.0.23->-r requirements.txt (line 43)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe==0.0.23->-r requirements.txt (line 43)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe==0.0.23->-r requirements.txt (line 43)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe==0.0.23->-r requirements.txt (line 43)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe==0.0.23->-r requirements.txt (line 43)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe==0.0.23->-r requirements.txt (line 43)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe==0.0.23->-r requirements.txt (line 43)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe==0.0.23->-r requirements.txt (line 43)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe==0.0.23->-r requirements.txt (line 43)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe==0.0.23->-r requirements.txt (line 43)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe==0.0.23->-r requirements.txt (line 43)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe==0.0.23->-r requirements.txt (line 43)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe==0.0.23->-r requirements.txt (line 43)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe==0.0.23->-r requirements.txt (line 43)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->torchcrepe==0.0.23->-r requirements.txt (line 43)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->torchcrepe==0.0.23->-r requirements.txt (line 43)) (1.5.3)
# Collecting hyper-connections>=0.1.8 (from local-attention->torchfcpe->-r requirements.txt (line 45))
#   Downloading hyper_connections-0.4.10-py3-none-any.whl.metadata (7.2 kB)
# Collecting torch-einops-utils>=0.0.20 (from hyper-connections>=0.1.8->local-attention->torchfcpe->-r requirements.txt (line 45))
#   Downloading torch_einops_utils-0.0.32-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.48.0->-r requirements.txt (line 9)) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.48.0->-r requirements.txt (line 9)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.48.0->-r requirements.txt (line 9)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.48.0->-r requirements.txt (line 9)) (0.30.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.14.0->gradio==3.48.0->-r requirements.txt (line 9)) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.14.0->gradio==3.48.0->-r requirements.txt (line 9)) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.14.0->gradio==3.48.0->-r requirements.txt (line 9)) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=0.14.0->gradio==3.48.0->-r requirements.txt (line 9)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=0.14.0->gradio==3.48.0->-r requirements.txt (line 9)) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub>=0.14.0->gradio==3.48.0->-r requirements.txt (line 9)) (0.1.2)
# Downloading librosa-0.10.2-py3-none-any.whl (260 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.0/260.0 kB 25.5 MB/s eta 0:00:00
# Downloading gradio-3.48.0-py3-none-any.whl (20.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 32.6 MB/s eta 0:00:00
# Downloading torchcrepe-0.0.23-py3-none-any.whl (72.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.3/72.3 MB 10.5 MB/s eta 0:00:00
# Downloading fastapi-0.88.0-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 6.0 MB/s eta 0:00:00
# Downloading gradio_client-0.6.1-py3-none-any.whl (299 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 31.5 MB/s eta 0:00:00
# Downloading starlette-0.22.0-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 7.8 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 96.4 MB/s eta 0:00:00
# Downloading faiss_cpu-1.13.2-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (23.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 86.0 MB/s eta 0:00:00
# Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Downloading tensorboardx-2.6.5-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 10.1 MB/s eta 0:00:00
# Downloading json5-0.14.0-py3-none-any.whl (36 kB)
# Downloading matplotlib-3.9.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 102.5 MB/s eta 0:00:00
# Downloading praat_parselmouth-0.4.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 99.0 MB/s eta 0:00:00
# Downloading pillow-10.4.0-cp312-cp312-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 119.5 MB/s eta 0:00:00
# Downloading resampy-0.4.3-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 105.3 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading onnxruntime_gpu-1.26.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (277.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.0/277.0 MB 4.5 MB/s eta 0:00:00
# Downloading torchfcpe-0.0.4-py3-none-any.whl (40.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 MB 17.3 MB/s eta 0:00:00
# Downloading av-17.0.1-cp311-abi3-manylinux_2_28_x86_64.whl (36.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.3/36.3 MB 62.2 MB/s eta 0:00:00
# Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 16.6 MB/s eta 0:00:00
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading MarkupSafe-2.1.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (28 kB)
# Downloading pydantic-1.10.26-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 98.2 MB/s eta 0:00:00
# Downloading sacrebleu-2.6.0-py3-none-any.whl (100 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 11.4 MB/s eta 0:00:00
# Downloading websockets-11.0.3-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.1/118.1 kB 13.4 MB/s eta 0:00:00
# Downloading bitarray-3.8.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (343 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 343.6/343.6 kB 31.6 MB/s eta 0:00:00
# Downloading local_attention-1.11.2-py3-none-any.whl (9.5 kB)
# Downloading hyper_connections-0.4.10-py3-none-any.whl (29 kB)
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Downloading torch_einops_utils-0.0.32-py3-none-any.whl (7.3 kB)
# Building wheels for collected packages: pyworld, ffmpy, fairseq
#   Building wheel for pyworld (pyproject.toml) ... done
#   Created wheel for pyworld: filename=pyworld-0.3.2-cp312-cp312-linux_x86_64.whl size=941009 sha256=4c61f893b2e5a11bf0fda66ff26f1ac179fad390cc19b5fde906531f966cec02
#   Stored in directory: /root/.cache/pip/wheels/c8/b9/af/98f6b9ad793c08fb9f90774a530a05e541426623813391193f
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.1-py3-none-any.whl size=5578 sha256=52292a35f92a25e59ae1504126327415cf9d2c73f7ecf12a63266cf7d67cf72b
#   Stored in directory: /root/.cache/pip/wheels/d2/26/84/f427a6f0b6644de658acc90bfd93a390fa33481db44b41196d

# %%
# @title 下载基础模型
# !apt install -y aria2
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/D32k.pth -d /content/RVC-Retrieval-based-Voice-Conversion-Colab/pretrained -o D32k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/D40k.pth -d /content/RVC-Retrieval-based-Voice-Conversion-Colab/pretrained -o D40k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/D48k.pth -d /content/RVC-Retrieval-based-Voice-Conversion-Colab/pretrained -o D48k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/G32k.pth -d /content/RVC-Retrieval-based-Voice-Conversion-Colab/pretrained -o G32k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/G40k.pth -d /content/RVC-Retrieval-based-Voice-Conversion-Colab/pretrained -o G40k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/G48k.pth -d /content/RVC-Retrieval-based-Voice-Conversion-Colab/pretrained -o G48k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/f0D32k.pth -d /content/RVC-Retrieval-based-Voice-Conversion-Colab/pretrained -o f0D32k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/f0D40k.pth -d /content/RVC-Retrieval-based-Voice-Conversion-Colab/pretrained -o f0D40k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/f0D48k.pth -d /content/RVC-Retrieval-based-Voice-Conversion-Colab/pretrained -o f0D48k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/f0G32k.pth -d /content/RVC-Retrieval-based-Voice-Conversion-Colab/pretrained -o f0G32k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/f0G40k.pth -d /content/RVC-Retrieval-based-Voice-Conversion-Colab/pretrained -o f0G40k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/f0G48k.pth -d /content/RVC-Retrieval-based-Voice-Conversion-Colab/pretrained -o f0G48k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/D32k.pth -d /content/RVC-Retrieval-based-Voice-Conversion-Colab/pretrained_v2 -o D32k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/D40k.pth -d /content/RVC-Retrieval-based-Voice-Conversion-Colab/pretrained_v2 -o D40k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/D48k.pth -d /content/RVC-Retrieval-based-Voice-Conversion-Colab/pretrained_v2 -o D48k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/G32k.pth -d /content/RVC-Retrieval-based-Voice-Conversion-Colab/pretrained_v2 -o G32k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/G40k.pth -d /content/RVC-Retrieval-based-Voice-Conversion-Colab/pretrained_v2 -o G40k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/G48k.pth -d /content/RVC-Retrieval-based-Voice-Conversion-Colab/pretrained_v2 -o G48k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/f0D32k.pth -d /content/RVC-Retrieval-based-Voice-Conversion-Colab/pretrained_v2 -o f0D32k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/f0D40k.pth -d /content/RVC-Retrieval-based-Voice-Conversion-Colab/pretrained_v2 -o f0D40k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/f0D48k.pth -d /content/RVC-Retrieval-based-Voice-Conversion-Colab/pretrained_v2 -o f0D48k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/f0G32k.pth -d /content/RVC-Retrieval-based-Voice-Conversion-Colab/pretrained_v2 -o f0G32k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/f0G40k.pth -d /content/RVC-Retrieval-based-Voice-Conversion-Colab/pretrained_v2 -o f0G40k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/f0G48k.pth -d /content/RVC-Retrieval-based-Voice-Conversion-Colab/pretrained_v2 -o f0G48k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/uvr5_weights/HP2-人声vocals+非人声instrumentals.pth -d /content/RVC-Retrieval-based-Voice-Conversion-Colab/uvr5_weights -o HP2-人声vocals+非人声instrumentals.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/uvr5_weights/HP5-主旋律人声vocals+其他instrumentals.pth -d /content/RVC-Retrieval-based-Voice-Conversion-Colab/uvr5_weights -o HP5-主旋律人声vocals+其他instrumentals.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/spaces/zomehwh/rvc-models/resolve/main/hubert_base.pt -d /content/RVC-Retrieval-based-Voice-Conversion-Colab/assets/hubert -o hubert_base.pt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/rmvpe.pt -d /content/RVC-Retrieval-based-Voice-Conversion-Colab/assets/rmvpe -o rmvpe.pt

# %%
# @title 挂载谷歌云盘

from google.colab import drive

drive.mount("/content/drive")

# %%
# @title 从谷歌云盘加载打包好的数据集到/content/dataset

# @markdown 数据集位置
DATASET = "/content/drive/MyDrive/datasets/RVC/src.zip"  # @param {type:"string"}


# !mkdir -p /content/dataset
# !unzip -d /content/dataset -B {DATASET}

# %%
# @title 从谷歌云盘恢复pth （初次使用不需要执行）
# @markdown 需要自己查看logs文件夹下模型的文件名，手动修改下方命令末尾的文件名

# @markdown 模型名
MODELNAME = "lulu"  # @param {type:"string"}
# @markdown 模型epoch
MODELEPOCH = 7500  # @param {type:"integer"}

# !mkdir -p /content/RVC-Retrieval-based-Voice-Conversion-Colab/logs/{MODELNAME}

# !cp /content/drive/MyDrive/{MODELNAME}_D_{MODELEPOCH}.pth /content/RVC-Retrieval-based-Voice-Conversion-Colab/logs/{MODELNAME}/G_{MODELEPOCH}.pth
# !cp /content/drive/MyDrive/{MODELNAME}_G_{MODELEPOCH}.pth /content/RVC-Retrieval-based-Voice-Conversion-Colab/logs/{MODELNAME}/D_{MODELEPOCH}.pth
# !cp /content/drive/MyDrive/*.index /content/
# !cp /content/drive/MyDrive/*.npy /content/
# !cp /content/drive/MyDrive/{MODELNAME}{MODELEPOCH}.pth /content/RVC-Retrieval-based-Voice-Conversion-Colab/weights/{MODELNAME}.pth

# %% [markdown]
# # Web运行RVC

# %%
# @title 方案一：直接运行脚本（使用Gradio获得web访问）
# %cd /content/RVC-Retrieval-based-Voice-Conversion-Colab
#%load_ext tensorboard
#%tensorboard --logdir /content/RVC-Retrieval-based-Voice-Conversion-Colab/logs
# !python infer-web.py --colab --pycmd python3 --port 7890

# %%
# @title 方案二：使用pyngrok运行脚本
#%load_ext tensorboard
#%tensorboard --logdir /content/RVC-Retrieval-based-Voice-Conversion-Colab/logs
# !pip install pyngrok
from pyngrok import ngrok
# @markdown Ngrok Authtoken 在 https://dashboard.ngrok.com 申请
Authtoken = ""  # @param {type:"string"}
ngrok.set_auth_token(Authtoken)       # 在 https://dashboard.ngrok.com 申请
# 假设 Gradio 启动在 7860 端口
public_url = ngrok.connect(7860, "http")
print("🌐 ngrok 公网访问地址:", public_url)
# 然后启动你的 WebUI，保证监听 0.0.0.0:7860
# !python infer-web.py --pycmd python3 --port 7860

# %%
# @title 模型文件备份到谷歌云盘
# @markdown 需要自己查看logs文件夹下模型的文件名，手动修改下方命令末尾的文件名

# @markdown 模型名
MODELNAME = "jst_colab"  # @param {type:"string"}
# @markdown 模型epoch
MODELEPOCH = 1520  # @param {type:"integer"}

# !cp /content/RVC-Retrieval-based-Voice-Conversion-Colab/logs/{MODELNAME}/G_{MODELEPOCH}.pth /content/drive/MyDrive/{MODELNAME}_D_{MODELEPOCH}.pth
# !cp /content/RVC-Retrieval-based-Voice-Conversion-Colab/logs/{MODELNAME}/D_{MODELEPOCH}.pth /content/drive/MyDrive/{MODELNAME}_G_{MODELEPOCH}.pth
# !cp /content/RVC-Retrieval-based-Voice-Conversion-Colab/logs/{MODELNAME}/added_*.index /content/drive/MyDrive/
# !cp /content/RVC-Retrieval-based-Voice-Conversion-Colab/logs/{MODELNAME}/total_*.npy /content/drive/MyDrive/

# !cp /content/RVC-Retrieval-based-Voice-Conversion-Colab/weights/{MODELNAME}.pth /content/drive/MyDrive/{MODELNAME}{MODELEPOCH}.pth

# %% [markdown]
# # 若尝试运行Web界面时提示执行代码被禁止则可以使用指令来运行脚本进行模型训练

# %%
# @title 音频文件预处理
# @markdown 模型名
MODELNAME = "lulu"  # @param {type:"string"}
# @markdown 采样率
BITRATE = 48000  # @param {type:"integer"}
# @markdown 使用的进程数
THREADCOUNT = 8  # @param {type:"integer"}

# !python trainset_preprocess_pipeline_print.py /content/dataset {BITRATE} {THREADCOUNT} logs/{MODELNAME} True

# %%
# @title 提取音高特征
# @markdown 模型名
MODELNAME = "lulu"  # @param {type:"string"}
# @markdown 使用的进程数
THREADCOUNT = 8  # @param {type:"integer"}
# @markdown 音高提取算法 可选"harvest" "pm" "dio" "rmvpe"
ALGO = "rmvpe"  # @param {type:"string"}

# !python3 extract_f0_print.py logs/{MODELNAME} {THREADCOUNT} {ALGO}

# !python3 extract_feature_print.py cpu 1 0 0 logs/{MODELNAME} True

# %%
# @title 训练模型
# %load_ext tensorboard
# %tensorboard --logdir /content/RVC-Retrieval-based-Voice-Conversion-Colab/logs
# @markdown 模型名
MODELNAME = "lulu"  # @param {type:"string"}
# Colab只有单卡，故无需考虑
USEGPU = "0"
# @markdown 批大小
BATCHSIZE = 32  # @param {type:"integer"}
# @markdown 停止的epoch
MODELEPOCH = 3200  # @param {type:"integer"}
# @markdown 保存epoch间隔
EPOCHSAVE = 100  # @param {type:"integer"}
# @markdown 采样率
MODELSAMPLE = "48k"  # @param {type:"string"}
# @markdown 是否缓存训练集
CACHEDATA = 1  # @param {type:"integer"}
# @markdown 是否仅保存最新的ckpt文件
ONLYLATEST = 0  # @param {type:"integer"}

# !python3 train_nsf_sim_cache_sid_load_pretrain.py -e lulu -sr {MODELSAMPLE} -f0 1 -bs {BATCHSIZE} -g {USEGPU} -te {MODELEPOCH} -se {EPOCHSAVE} -pg pretrained/f0G{MODELSAMPLE}.pth -pd pretrained/f0D{MODELSAMPLE}.pth -l {ONLYLATEST} -c {CACHEDATA}

# %%
# @title 模型文件备份到谷歌云盘
# @markdown 需要自己查看logs文件夹下模型的文件名，手动修改下方命令末尾的文件名

# @markdown 模型名
MODELNAME = "lulu"  # @param {type:"string"}
# @markdown 模型epoch
MODELEPOCH = 9600  # @param {type:"integer"}

# !cp /content/RVC-Retrieval-based-Voice-Conversion-Colab/logs/{MODELNAME}/G_{MODELEPOCH}.pth /content/drive/MyDrive/{MODELNAME}_D_{MODELEPOCH}.pth
# !cp /content/RVC-Retrieval-based-Voice-Conversion-Colab/logs/{MODELNAME}/D_{MODELEPOCH}.pth /content/drive/MyDrive/{MODELNAME}_G_{MODELEPOCH}.pth
# !cp /content/RVC-Retrieval-based-Voice-Conversion-Colab/logs/{MODELNAME}/added_*.index /content/drive/MyDrive/
# !cp /content/RVC-Retrieval-based-Voice-Conversion-Colab/logs/{MODELNAME}/total_*.npy /content/drive/MyDrive/

# !cp /content/RVC-Retrieval-based-Voice-Conversion-Colab/weights/{MODELNAME}.pth /content/drive/MyDrive/{MODELNAME}{MODELEPOCH}.pth
